# %%
import matplotlib.pyplot as plt
from nachbarstrom import LocalImgDataProvider

# %%
basedir = "/home/tomas_ruiz_te_gmail_com/labelbox-download/"
provider = LocalImgDataProvider(basedir=basedir)

# %% [markdown]
# ### Rerun the cell below for each new img

# %%
x, y = provider(1)
fig, ax = plt.subplots(1,3, sharey=True, figsize=(12,4))
ax[0].imshow(x[0,...], aspect="auto")
ax[1].imshow(y[0,...,0], aspect="auto"); ax[1].set_title("Suitable Area")
ax[2].imshow(y[0,...,1], aspect="auto"); ax[2].set_title("Unusable Area")
# Out:
# Text(0.5,1,'Unusable Area')
