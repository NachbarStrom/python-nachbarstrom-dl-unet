# %%
from PIL import Image
import numpy as np

# %%
fname = "/home/tomas/Desktop/labelbox-download/cjkpl0mpo31wj07869qgb3idt_original.png"

# %%
img = Image.open(fname)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x640 at 0x7FE01CF51588>

# %%
b, g, r = img.split()
Image.merge("RGB", (r, b, g))
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7FE01CF5A780>

# %%
a = np.array(img)

# %%
a.shape
# Out:
# (640, 640, 3)

# %%
img2 = img.convert("1")

# %%
b = np.array(img2)

# %%
img2
# Out:
# <PIL.Image.Image image mode=1 size=640x640 at 0x7FE01CF45B00>

# %%
x = np.expand_dims(b, axis=2).astype("float")

# %%
x.shape
# Out:
# (640, 640, 1)

# %%
x[..., 0].shape
# Out:
# (640, 640)

# %%
one = 1.0
